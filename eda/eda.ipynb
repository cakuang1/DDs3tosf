# %%
import sys
import pandas as pd
import requests

# %%
url = 'https://raw.githubusercontent.com/ralfsantacruz/Doordash-Analytics/master/resources/analytics.csv'

df = pd.read_csv(url)
# Out:
#        Unnamed: 0 Customer_placed_order_datetime  \
# 0               0                    14 20:27:45
# 1               1                    07 20:16:28
# 2               2                    13 19:35:09
# 3               3                    22 19:47:53
# 4               4                    03 19:01:52
# ...           ...                            ...
# 18073       18073                    20 00:39:30
# 18074       18074                    26 19:59:56
# 18075       18075                    30 18:20:01
# 18076       18076                    27 21:48:21
# 18077       18077                    30 01:58:19
#
#       Placed_order_with_restaurant_datetime Driver_at_restaurant_datetime  \
# 0                               14 20:29:41                   14 20:39:32
# 1                               07 20:17:32                   07 20:36:00
# 2                               13 19:39:26                   13 20:28:16
# 3                               22 19:56:08                   22 20:01:20
# ...
